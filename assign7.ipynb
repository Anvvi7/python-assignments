# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

roll_number = 102317133
np.random.seed(roll_number)

sales_data = np.random.randint(1000, 5001, size=(12, 4))

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
categories = ["Electronics", "Clothing", "Home & Kitchen", "Sports"]
df = pd.DataFrame(sales_data, columns=categories, index=months)

print(df.head())
print(df.describe())

total_sales_per_category = df.sum()
total_sales_per_month = df.sum(axis=1)

growth_rates = df.pct_change().mean()

df["Total Sales"] = df.sum(axis=1)
df["Growth Rate"] = df["Total Sales"].pct_change() * 100

if roll_number % 2 == 0:
    df["Electronics"] = df["Electronics"] * 0.90
else:
    df["Clothing"] = df["Clothing"] * 0.85

plt.figure(figsize=(10, 5))
for category in categories:
    plt.plot(df.index, df[category], label=category)
plt.legend()
plt.title("Monthly Sales Trends")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

plt.figure(figsize=(8, 5))
sns.boxplot(data=df[categories])
plt.title("Sales Distribution by Category")
plt.show()
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         4904      1693            4602    1941
# Feb         2987      2394            2512    4451
# Mar         1117      1041            2648    1147
# Apr         2505      3158            4236    2748
# May         4356      4671            4946    2627
#        Electronics     Clothing  Home & Kitchen       Sports
# count    12.000000    12.000000       12.000000    12.000000
# mean   3310.083333  3352.750000     3023.500000  2000.416667
# std    1329.183513  1299.517402     1371.221718   996.453298
# min    1117.000000  1041.000000     1123.000000  1015.000000
# 25%    2517.000000  2267.250000     2220.000000  1130.250000
# 50%    3535.500000  3772.500000     2842.000000  1848.000000
# 75%    4399.500000  4317.750000     4318.500000  2439.500000
# max    4904.000000  4766.000000     4946.000000  4451.000000

# %%
import numpy as np
array = np.array([[1, -2, 3],[-4, 5, -6]])
abs_values = np.abs(array)
print("Element-wise Absolute Values:", abs_values)

percentile_flat = np.percentile(array, [25, 50, 75], axis=None)
percentile_col = np.percentile(array, [25, 50, 75], axis=0)
percentile_row = np.percentile(array, [25, 50, 75], axis=1)

print("Percentiles Flattened:", percentile_flat)
print("Percentiles Per Column:", percentile_col)
print("Percentiles Per Row:", percentile_row)

mean_flat = np.mean(array)
median_flat = np.median(array)
std_flat = np.std(array)

mean_col = np.mean(array, axis=0)
median_col = np.median(array, axis=0)
std_col = np.std(array, axis=0)

mean_row = np.mean(array, axis=1)
median_row = np.median(array, axis=1)
std_row = np.std(array, axis=1)

print("Mean Flattened:", mean_flat,
      "Median:", median_flat,
      "Std Dev:", std_flat)
print("Mean Per Column:", mean_col)
print("Median Per Column:", median_col)
print("Std Dev Per Column:", std_col)
print("Mean Per Row:", mean_row)
print("Median Per Row:", median_row)
print("Std Dev Per Row:", std_row)
# Out:
# Element-wise Absolute Values: [[1 2 3]
#  [4 5 6]]
# Percentiles Flattened: [-3.5 -0.5  2.5]
# Percentiles Per Column: [[-2.75 -0.25 -3.75]
#  [-1.5   1.5  -1.5 ]
#  [-0.25  3.25  0.75]]
# Percentiles Per Row: [[-0.5 -5. ]
#  [ 1.  -4. ]
#  [ 2.   0.5]]
# Mean Flattened: -0.5 Median: -0.5 Std Dev: 3.8622100754188224
# Mean Per Column: [-1.5  1.5 -1.5]
# Median Per Column: [-1.5  1.5 -1.5]
# Std Dev Per Column: [2.5 3.5 4.5]
# Mean Per Row: [ 0.66666667 -1.66666667]
# Median Per Row: [ 1. -4.]
# Std Dev Per Row: [2.05480467 4.78423336]

# %%
a = np.array([-1.8, -1.6, -0.5, 0.5,1.6, 1.8, 3.0])
print(np.floor(a), np.ceil(a), np.trunc(a), np.round(a))
# Out:
# [-2. -2. -1.  0.  1.  1.  3.] [-1. -1. -0.  1.  2.  2.  3.] [-1. -1. -0.  0.  1.  1.  3.] [-2. -2. -0.  0.  2.  2.  3.]

# %%
l = [1, 2, 3, 4, 5]
temp = l[1]
l[1] = l[2]
l[2] = temp
print("Final List:", l)
# Out:
# Final List: [1, 3, 2, 4, 5]

# %%
x = {10, 20, 30, 40, 50}
x = list(x)
x[3], x[4] = x[4], x[3]
x = set(x)
print("Swapped Set:", x)
# Out:
# Swapped Set: {40, 10, 50, 20, 30}
